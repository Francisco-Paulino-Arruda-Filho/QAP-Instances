# %%
import numpy as np
import random
import pandas as pd
import psutil
import os
import time
import glob
from typing import List, Tuple, Union, Optional
import csv

# %%
def gerar_array_replicavel(seed: int, tamanho: int) -> List[int]:
    random.seed(seed)
    vetor = list(range(tamanho))
    random.shuffle(vetor)
    return vetor

# %%
def calcular_aptidao_qap(
    solucao: Union[List[int], np.ndarray, List[List[int]]],
    matriz_fluxo: np.ndarray,
    matriz_distancia: np.ndarray
) -> int:
    solucao_flat: List[int] = []
    for x in solucao:
        if isinstance(x, (list, np.ndarray)):
            solucao_flat.extend(int(v) for v in x)
        else:
            solucao_flat.append(int(x))

    n: int = len(solucao_flat)
    custo: int = 0
    for i in range(n):
        for j in range(n):
            custo += matriz_fluxo[i][j] * matriz_distancia[solucao_flat[i]][solucao_flat[j]]
    return custo

# %%
def inicializar_feromonio(n: int, valor_inicial: float = 0.1) -> np.ndarray:
    return np.full((n, n), valor_inicial)

# %%
def construir_solucao_qap(
    feromonio: np.ndarray,
    alpha: float,
    beta: float,
    heuristica: np.ndarray
) -> List[int]:
    """
    feromonio -> memória coletiva das soluções anteriores 
    heuristica -> informação local que guia a escolha 
    alpha -> peso do feromônio
    beta -> peso da heurística
    """
    n: int = feromonio.shape[0]
    nao_visitados: List[int] = list(range(n))
    solucao: List[int] = []

    while nao_visitados:
        if not solucao:
            atual: int = random.choice(nao_visitados)
        else:
            ultima: int = solucao[-1]
            pesos: List[float] = []
            for prox in nao_visitados:
                tau: float = feromonio[ultima][prox] ** alpha
                eta: float = heuristica[ultima][prox] ** beta
                pesos.append(tau * eta)
            pesos_np: np.ndarray = np.array(pesos, dtype=float)
            if not np.isfinite(pesos_np).all() or pesos_np.sum() <= 0:
                pesos_np = np.ones_like(pesos_np) / len(pesos_np)
            else:
                pesos_np /= pesos_np.sum()
            atual = random.choices(nao_visitados, weights=pesos_np)[0]


        solucao.append(atual)
        nao_visitados.remove(atual)

    return solucao

# %%
def busca_local(
    solucao: List[int],
    fluxo: np.ndarray,
    distancia: np.ndarray,
    tempo_inicio_global: float = None,  
    tempo_global_max: float = None     
) -> List[int]:
    melhor: List[int] = solucao.copy()
    melhor_custo: int = calcular_aptidao_qap(melhor, fluxo, distancia)
    melhorou: bool = True
    
    while melhorou:
        if tempo_inicio_global and tempo_global_max:
            if (time.time() - tempo_inicio_global) > tempo_global_max:
                return melhor 
        
        melhorou = False
        for i in range(len(solucao) - 1):
            if tempo_inicio_global and tempo_global_max:
                if (time.time() - tempo_inicio_global) > tempo_global_max:
                    return melhor
            
            for j in range(i + 1, len(solucao)):
                nova: List[int] = melhor.copy()
                nova[i], nova[j] = nova[j], nova[i]
                custo_novo: int = calcular_aptidao_qap(nova, fluxo, distancia)
                if custo_novo < melhor_custo:
                    melhor, melhor_custo = nova, custo_novo
                    melhorou = True
    return melhor

# %%
def atualizar_feromonio(
    feromonio: np.ndarray,
    solucoes: List[List[int]],
    custos: List[int],
    rho: float,
    Q: float
) -> np.ndarray:
    feromonio *= (1 - rho)  
    for solucao, custo in zip(solucoes, custos):
        if custo <= 0 or not np.isfinite(custo):
            custo = 1e-6 
        deposito: float = Q / custo

        for i in range(len(solucao) - 1):
            feromonio[solucao[i]][solucao[i + 1]] += deposito
        feromonio[solucao[-1]][solucao[0]] += deposito
    return feromonio

# %%
def save_aco_iteration_results(
    file_name: str,
    instancia: str,
    iteration: int,
    ant_index: int,
    best_cost: float,
    current_cost: float,
    tempo_inicio_global: float
) -> None:
    """
    Salva resultados parciais da execução do ACO em um arquivo CSV no mesmo diretório.
    """
    path = file_name  

    header = [
        "instancia",
        "iteracao",
        "formiga",
        "melhor_custo",
        "custo_atual",
        "tempo_decorrido"
    ]
    write_header = not os.path.exists(path)

    with open(path, mode="a", newline="") as f:
        writer = csv.writer(f)
        if write_header:
            writer.writerow(header)
        writer.writerow([
            instancia,
            iteration,
            ant_index,
            best_cost,
            current_cost,
            round(time.time() - tempo_inicio_global, 3)
        ])

# %%
def aco_qap(
    fluxo: np.ndarray,
    distancia: np.ndarray,
    n_formigas: int = 10,
    alpha: float = 1,
    beta: float = 2,
    rho: float = 0.1,
    Q: float = 1,
    iter_max: int = 100,
    instancia: str = "desconhecida",
    tempo_inicio_global: float = None,
    tempo_global_max: float = None
) -> Tuple[List[int], int]:
    """
    Algoritmo de Otimização por Colônia de Formigas (ACO) puro com salvamento de resultados.
    """

    n: int = len(fluxo)
    heuristica: np.ndarray = 1 / (np.array(distancia) + 1e-10)
    feromonio: np.ndarray = inicializar_feromonio(n)

    melhor_solucao: Optional[List[int]] = None
    melhor_custo: float = float("inf")
    file_name = f"iteracoes_{instancia}_ACO.csv"

    for i in range(iter_max):
        if tempo_inicio_global and tempo_global_max:
            if (time.time() - tempo_inicio_global) > tempo_global_max:
                return melhor_solucao if melhor_solucao else [], int(melhor_custo)

        solucoes: List[List[int]] = []
        custos: List[int] = []

        for j in range(n_formigas):
            if tempo_inicio_global and tempo_global_max:
                if (time.time() - tempo_inicio_global) > tempo_global_max:
                    return melhor_solucao if melhor_solucao else [], int(melhor_custo)

            s: List[int] = construir_solucao_qap(feromonio, alpha, beta, heuristica)
            custo: int = calcular_aptidao_qap(s, fluxo, distancia)

            solucoes.append(s)
            custos.append(custo)

            if custo < melhor_custo:
                melhor_solucao, melhor_custo = s, custo

            save_aco_iteration_results(
                file_name=file_name,
                instancia=instancia,
                iteration=i,
                ant_index=j,
                best_cost=melhor_custo,
                current_cost=custo,
                tempo_inicio_global=tempo_inicio_global or time.time()
            )

        feromonio = atualizar_feromonio(feromonio, solucoes, custos, rho, Q)

        save_aco_iteration_results(
            file_name=file_name,
            instancia=instancia,
            iteration=i,
            ant_index=-1,  
            best_cost=melhor_custo,
            current_cost=min(custos),
            tempo_inicio_global=tempo_inicio_global or time.time()
        )

    return melhor_solucao if melhor_solucao else [], int(melhor_custo)

# %%
def ler_qap_com_n(caminho: str) -> Tuple[int, pd.DataFrame, pd.DataFrame]:
    with open(caminho, "r") as f:
        dados: List[int] = list(map(int, f.read().split()))

    n: int = dados[0]
    valores: List[int] = dados[1:]

    total_esperado: int = 2 * n * n
    if len(valores) != total_esperado:
        raise ValueError(f"Esperado {total_esperado} valores, mas encontrado {len(valores)}.")

    flow_flat: List[int] = valores[: n * n]
    dist_flat: List[int] = valores[n * n :]

    flow_df: pd.DataFrame = pd.DataFrame([flow_flat[i * n : (i + 1) * n] for i in range(n)])
    dist_df: pd.DataFrame = pd.DataFrame([dist_flat[i * n : (i + 1) * n] for i in range(n)])

    return n, flow_df, dist_df

# %%
if __name__ == "__main__":
    arquivos = glob.glob("*.txt")

    tempo_global_max = 10 * 60  # 10 minutos por instância

    for arquivo in arquivos:
        nome_instancia = os.path.splitext(os.path.basename(arquivo))[0]

        n, flow_df, dist_df = ler_qap_com_n(arquivo)
        matriz_fluxo = np.array(flow_df.values.tolist())
        matriz_distancia = np.array(dist_df.values.tolist())

        resultados = []
        tempo_inicio_instancia = time.time()

        for seed in range(42, 52):
            tempo_decorrido_global = time.time() - tempo_inicio_instancia
            if tempo_decorrido_global >= tempo_global_max:
                print(f"\n Tempo limite global atingido para {nome_instancia}.")
                break

            random.seed(seed)
            np.random.seed(seed)

            process = psutil.Process(os.getpid())
            tempo_inicio_seed = time.time()

            parametros = {
                "n_formigas": random.randint(5, 20),
                "alpha": random.uniform(0.5, 2.0),
                "beta": random.uniform(1.0, 3.0),
                "rho": random.uniform(0.05, 0.2),
                "Q": 1,
                "iter_max": random.randint(50, 150) 
            }

            melhor_solucao, melhor_custo = aco_qap(
                fluxo=matriz_fluxo,
                distancia=matriz_distancia,
                instancia=nome_instancia,
                tempo_inicio_global=tempo_inicio_instancia,
                tempo_global_max=tempo_global_max,
                **parametros
            )

            tempo_fim_seed = time.time()

            tempo_restante_global = max(0, tempo_global_max - (tempo_inicio_seed - tempo_inicio_instancia))
            tempo_execucao = min(tempo_fim_seed - tempo_inicio_seed, tempo_restante_global)

            try:
                memoria_usada = process.memory_info().peak_wset / (1024 * 1024)
            except AttributeError:
                memoria_usada = process.memory_info().rss / (1024 * 1024)

            resultados.append({
                "instancia": nome_instancia,
                "seed": seed,
                "melhor_solucao": melhor_solucao,
                "custo": melhor_custo,
                "tempo_execucao_segundos": round(tempo_execucao, 2),
                "memoria_usada_MB": round(memoria_usada, 2),
                **parametros
            })

            print(f"[{nome_instancia}] Seed {seed} finalizada. "
                  f"Custo: {melhor_custo} | Memória usada: {round(memoria_usada, 2)} MB")

        df_resultados = pd.DataFrame(resultados)
        df_resultados.to_csv(f"resultados_{nome_instancia}_ACO_10min.csv", index=False)

        print(f"\nResultados da instância {nome_instancia} salvos em resultados_{nome_instancia}_ACO.csv")
# Out:
# [Ste36a] Seed 42 finalizada. Custo: 18320 | Memória usada: 91.08 MB
# [Ste36a] Seed 43 finalizada. Custo: 18994 | Memória usada: 91.08 MB
# [Ste36a] Seed 44 finalizada. Custo: 18230 | Memória usada: 91.08 MB
# [Ste36a] Seed 45 finalizada. Custo: 18524 | Memória usada: 91.08 MB
# [Ste36a] Seed 46 finalizada. Custo: 18628 | Memória usada: 91.08 MB
# [Ste36a] Seed 47 finalizada. Custo: 19252 | Memória usada: 91.08 MB
# [Ste36a] Seed 48 finalizada. Custo: 18286 | Memória usada: 91.08 MB
# [Ste36a] Seed 49 finalizada. Custo: 18290 | Memória usada: 91.08 MB
# [Ste36a] Seed 50 finalizada. Custo: 18418 | Memória usada: 91.08 MB
# [Ste36a] Seed 51 finalizada. Custo: 18898 | Memória usada: 91.08 MB
#
# Resultados da instância Ste36a salvos em resultados_Ste36a_ACO.csv
# [Ste36b] Seed 42 finalizada. Custo: 58490 | Memória usada: 91.08 MB
# [Ste36b] Seed 43 finalizada. Custo: 54548 | Memória usada: 91.08 MB
# [Ste36b] Seed 44 finalizada. Custo: 55652 | Memória usada: 91.08 MB
# [Ste36b] Seed 45 finalizada. Custo: 57164 | Memória usada: 91.08 MB
# [Ste36b] Seed 46 finalizada. Custo: 58490 | Memória usada: 91.08 MB
# [Ste36b] Seed 47 finalizada. Custo: 56022 | Memória usada: 91.08 MB
# [Ste36b] Seed 48 finalizada. Custo: 58426 | Memória usada: 91.08 MB
# [Ste36b] Seed 49 finalizada. Custo: 58710 | Memória usada: 91.08 MB
# [Ste36b] Seed 50 finalizada. Custo: 54568 | Memória usada: 91.08 MB
# [Ste36b] Seed 51 finalizada. Custo: 56436 | Memória usada: 91.08 MB
#
# Resultados da instância Ste36b salvos em resultados_Ste36b_ACO.csv
# [Ste36c] Seed 42 finalizada. Custo: 15176586 | Memória usada: 91.08 MB
# [Ste36c] Seed 43 finalizada. Custo: 15301760 | Memória usada: 91.08 MB
# [Ste36c] Seed 44 finalizada. Custo: 15024822 | Memória usada: 91.08 MB
# [Ste36c] Seed 45 finalizada. Custo: 15540328 | Memória usada: 91.08 MB
# [Ste36c] Seed 46 finalizada. Custo: 15332854 | Memória usada: 91.08 MB
# [Ste36c] Seed 47 finalizada. Custo: 14379088 | Memória usada: 91.08 MB
# [Ste36c] Seed 48 finalizada. Custo: 15410576 | Memória usada: 91.08 MB
# [Ste36c] Seed 49 finalizada. Custo: 15628944 | Memória usada: 91.08 MB
# [Ste36c] Seed 50 finalizada. Custo: 15165738 | Memória usada: 91.08 MB
# [Ste36c] Seed 51 finalizada. Custo: 15756082 | Memória usada: 91.08 MB
#
# Resultados da instância Ste36c salvos em resultados_Ste36c_ACO.csv
# [Tai12a] Seed 42 finalizada. Custo: 262280 | Memória usada: 91.08 MB
# [Tai12a] Seed 43 finalizada. Custo: 276240 | Memória usada: 91.08 MB
# [Tai12a] Seed 44 finalizada. Custo: 265614 | Memória usada: 91.08 MB
# [Tai12a] Seed 45 finalizada. Custo: 269672 | Memória usada: 91.08 MB
# [Tai12a] Seed 46 finalizada. Custo: 270208 | Memória usada: 91.08 MB
# [Tai12a] Seed 47 finalizada. Custo: 269672 | Memória usada: 91.08 MB
# [Tai12a] Seed 48 finalizada. Custo: 268760 | Memória usada: 91.08 MB
# [Tai12a] Seed 49 finalizada. Custo: 276340 | Memória usada: 91.08 MB
# [Tai12a] Seed 50 finalizada. Custo: 268760 | Memória usada: 91.08 MB
# [Tai12a] Seed 51 finalizada. Custo: 266502 | Memória usada: 91.08 MB
#
# Resultados da instância Tai12a salvos em resultados_Tai12a_ACO.csv
# [Tai12b] Seed 42 finalizada. Custo: 46878723 | Memória usada: 91.08 MB
# [Tai12b] Seed 43 finalizada. Custo: 51268371 | Memória usada: 91.08 MB
# [Tai12b] Seed 44 finalizada. Custo: 49950548 | Memória usada: 91.08 MB
# [Tai12b] Seed 45 finalizada. Custo: 49943325 | Memória usada: 91.08 MB
# [Tai12b] Seed 46 finalizada. Custo: 50219228 | Memória usada: 91.08 MB
# [Tai12b] Seed 47 finalizada. Custo: 45459464 | Memória usada: 91.08 MB
# [Tai12b] Seed 48 finalizada. Custo: 48178277 | Memória usada: 91.08 MB
# [Tai12b] Seed 49 finalizada. Custo: 48287546 | Memória usada: 91.08 MB
# [Tai12b] Seed 50 finalizada. Custo: 47715262 | Memória usada: 91.08 MB
# [Tai12b] Seed 51 finalizada. Custo: 49377477 | Memória usada: 91.08 MB
#
# Resultados da instância Tai12b salvos em resultados_Tai12b_ACO.csv
# [Tai15a] Seed 42 finalizada. Custo: 439522 | Memória usada: 91.08 MB
# [Tai15a] Seed 43 finalizada. Custo: 440534 | Memória usada: 91.08 MB
# [Tai15a] Seed 44 finalizada. Custo: 438192 | Memória usada: 91.08 MB
# [Tai15a] Seed 45 finalizada. Custo: 440242 | Memória usada: 91.08 MB
# [Tai15a] Seed 46 finalizada. Custo: 444004 | Memória usada: 91.08 MB
# [Tai15a] Seed 47 finalizada. Custo: 438192 | Memória usada: 91.08 MB
# [Tai15a] Seed 48 finalizada. Custo: 436604 | Memória usada: 91.08 MB
# [Tai15a] Seed 49 finalizada. Custo: 439090 | Memória usada: 91.08 MB
# [Tai15a] Seed 50 finalizada. Custo: 436488 | Memória usada: 91.08 MB
# [Tai15a] Seed 51 finalizada. Custo: 436838 | Memória usada: 91.08 MB
#
# Resultados da instância Tai15a salvos em resultados_Tai15a_ACO.csv
# [Tai15b] Seed 42 finalizada. Custo: 52792710 | Memória usada: 91.08 MB
# [Tai15b] Seed 43 finalizada. Custo: 53423121 | Memória usada: 91.08 MB
# [Tai15b] Seed 44 finalizada. Custo: 53079293 | Memória usada: 91.08 MB
# [Tai15b] Seed 45 finalizada. Custo: 53557434 | Memória usada: 91.08 MB
# [Tai15b] Seed 46 finalizada. Custo: 52916096 | Memória usada: 91.08 MB
# [Tai15b] Seed 47 finalizada. Custo: 52887679 | Memória usada: 91.08 MB
# [Tai15b] Seed 48 finalizada. Custo: 53143657 | Memória usada: 91.08 MB
# [Tai15b] Seed 49 finalizada. Custo: 53025608 | Memória usada: 91.08 MB
# [Tai15b] Seed 50 finalizada. Custo: 52964845 | Memória usada: 91.08 MB
# [Tai15b] Seed 51 finalizada. Custo: 53125717 | Memória usada: 91.08 MB
#
# Resultados da instância Tai15b salvos em resultados_Tai15b_ACO.csv
# [Tai17a] Seed 42 finalizada. Custo: 573168 | Memória usada: 91.08 MB
# [Tai17a] Seed 43 finalizada. Custo: 571060 | Memória usada: 91.08 MB
# [Tai17a] Seed 44 finalizada. Custo: 562850 | Memória usada: 91.08 MB
# [Tai17a] Seed 45 finalizada. Custo: 571642 | Memória usada: 91.08 MB
# [Tai17a] Seed 46 finalizada. Custo: 571728 | Memória usada: 91.08 MB
# [Tai17a] Seed 47 finalizada. Custo: 573226 | Memória usada: 91.08 MB
# [Tai17a] Seed 48 finalizada. Custo: 570822 | Memória usada: 91.08 MB
# [Tai17a] Seed 49 finalizada. Custo: 571060 | Memória usada: 91.08 MB
# [Tai17a] Seed 50 finalizada. Custo: 571060 | Memória usada: 91.08 MB
# [Tai17a] Seed 51 finalizada. Custo: 568294 | Memória usada: 91.08 MB
#
# Resultados da instância Tai17a salvos em resultados_Tai17a_ACO.csv
# [Tai20a] Seed 42 finalizada. Custo: 823338 | Memória usada: 91.08 MB
# [Tai20a] Seed 43 finalizada. Custo: 823604 | Memória usada: 91.08 MB
# [Tai20a] Seed 44 finalizada. Custo: 823310 | Memória usada: 91.08 MB
# [Tai20a] Seed 45 finalizada. Custo: 828270 | Memória usada: 91.08 MB
# [Tai20a] Seed 46 finalizada. Custo: 826404 | Memória usada: 91.08 MB
# [Tai20a] Seed 47 finalizada. Custo: 822164 | Memória usada: 91.08 MB
# [Tai20a] Seed 48 finalizada. Custo: 814376 | Memória usada: 91.08 MB
# [Tai20a] Seed 49 finalizada. Custo: 821328 | Memória usada: 91.08 MB
# [Tai20a] Seed 50 finalizada. Custo: 819970 | Memória usada: 91.08 MB
# [Tai20a] Seed 51 finalizada. Custo: 818406 | Memória usada: 91.08 MB
#
# Resultados da instância Tai20a salvos em resultados_Tai20a_ACO.csv
# [Tai20b] Seed 42 finalizada. Custo: 188220878 | Memória usada: 91.08 MB
# [Tai20b] Seed 43 finalizada. Custo: 158238346 | Memória usada: 91.08 MB
# [Tai20b] Seed 44 finalizada. Custo: 166833588 | Memória usada: 91.08 MB
# [Tai20b] Seed 45 finalizada. Custo: 169782233 | Memória usada: 91.08 MB
# [Tai20b] Seed 46 finalizada. Custo: 150511735 | Memória usada: 91.08 MB
# [Tai20b] Seed 47 finalizada. Custo: 176461918 | Memória usada: 91.08 MB
# [Tai20b] Seed 48 finalizada. Custo: 152108858 | Memória usada: 91.08 MB
# [Tai20b] Seed 49 finalizada. Custo: 184600477 | Memória usada: 91.08 MB
# [Tai20b] Seed 50 finalizada. Custo: 162363537 | Memória usada: 91.08 MB
# [Tai20b] Seed 51 finalizada. Custo: 180837710 | Memória usada: 91.08 MB
#
# Resultados da instância Tai20b salvos em resultados_Tai20b_ACO.csv
