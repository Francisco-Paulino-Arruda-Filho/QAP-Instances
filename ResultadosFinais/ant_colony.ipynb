# %%
import numpy as np
import random
import pandas as pd
import psutil
import os
import time
import glob
from typing import List, Tuple, Union, Optional
import csv

# %%
def gerar_array_replicavel(seed: int, tamanho: int) -> List[int]:
    random.seed(seed)
    vetor = list(range(tamanho))
    random.shuffle(vetor)
    return vetor

# %%
def calcular_aptidao_qap(
    solucao: Union[List[int], np.ndarray, List[List[int]]],
    matriz_fluxo: np.ndarray,
    matriz_distancia: np.ndarray
) -> int:
    solucao_flat: List[int] = []
    for x in solucao:
        if isinstance(x, (list, np.ndarray)):
            solucao_flat.extend(int(v) for v in x)
        else:
            solucao_flat.append(int(x))

    n: int = len(solucao_flat)
    custo: int = 0
    for i in range(n):
        for j in range(n):
            custo += matriz_fluxo[i][j] * matriz_distancia[solucao_flat[i]][solucao_flat[j]]
    return custo

# %%
def inicializar_feromonio(n: int, valor_inicial: float = 0.1) -> np.ndarray:
    return np.full((n, n), valor_inicial)

# %%
def construir_solucao_qap(
    feromonio: np.ndarray,
    alpha: float,
    beta: float,
    heuristica: np.ndarray
) -> List[int]:
    """
    feromonio -> memória coletiva das soluções anteriores 
    heuristica -> informação local que guia a escolha 
    alpha -> peso do feromônio
    beta -> peso da heurística
    """
    n: int = feromonio.shape[0]
    nao_visitados: List[int] = list(range(n))
    solucao: List[int] = []

    while nao_visitados:
        if not solucao:
            atual: int = random.choice(nao_visitados)
        else:
            ultima: int = solucao[-1]
            pesos: List[float] = []
            for prox in nao_visitados:
                tau: float = feromonio[ultima][prox] ** alpha
                eta: float = heuristica[ultima][prox] ** beta
                pesos.append(tau * eta)
            pesos_np: np.ndarray = np.array(pesos, dtype=float)
            if not np.isfinite(pesos_np).all() or pesos_np.sum() <= 0:
                pesos_np = np.ones_like(pesos_np) / len(pesos_np)
            else:
                pesos_np /= pesos_np.sum()
            atual = random.choices(nao_visitados, weights=pesos_np)[0]


        solucao.append(atual)
        nao_visitados.remove(atual)

    return solucao

# %%
def busca_local(
    solucao: List[int],
    fluxo: np.ndarray,
    distancia: np.ndarray,
    tempo_inicio_global: float = None,  
    tempo_global_max: float = None     
) -> List[int]:
    melhor: List[int] = solucao.copy()
    melhor_custo: int = calcular_aptidao_qap(melhor, fluxo, distancia)
    melhorou: bool = True
    
    while melhorou:
        if tempo_inicio_global and tempo_global_max:
            if (time.time() - tempo_inicio_global) > tempo_global_max:
                return melhor 
        
        melhorou = False
        for i in range(len(solucao) - 1):
            if tempo_inicio_global and tempo_global_max:
                if (time.time() - tempo_inicio_global) > tempo_global_max:
                    return melhor
            
            for j in range(i + 1, len(solucao)):
                nova: List[int] = melhor.copy()
                nova[i], nova[j] = nova[j], nova[i]
                custo_novo: int = calcular_aptidao_qap(nova, fluxo, distancia)
                if custo_novo < melhor_custo:
                    melhor, melhor_custo = nova, custo_novo
                    melhorou = True
    return melhor

# %%
def atualizar_feromonio(
    feromonio: np.ndarray,
    solucoes: List[List[int]],
    custos: List[int],
    rho: float,
    Q: float
) -> np.ndarray:
    feromonio *= (1 - rho)  
    for solucao, custo in zip(solucoes, custos):
        if custo <= 0 or not np.isfinite(custo):
            custo = 1e-6 
        deposito: float = Q / custo

        for i in range(len(solucao) - 1):
            feromonio[solucao[i]][solucao[i + 1]] += deposito
        feromonio[solucao[-1]][solucao[0]] += deposito
    return feromonio

# %%
def save_aco_iteration_results(
    file_name: str,
    instancia: str,
    iteration: int,
    ant_index: int,
    best_cost: float,
    current_cost: float,
    tempo_inicio_global: float
) -> None:
    """
    Salva resultados parciais da execução do ACO em um arquivo CSV no mesmo diretório.
    """
    path = file_name  

    header = [
        "instancia",
        "iteracao",
        "formiga",
        "melhor_custo",
        "custo_atual",
        "tempo_decorrido"
    ]
    write_header = not os.path.exists(path)

    with open(path, mode="a", newline="") as f:
        writer = csv.writer(f)
        if write_header:
            writer.writerow(header)
        writer.writerow([
            instancia,
            iteration,
            ant_index,
            best_cost,
            current_cost,
            round(time.time() - tempo_inicio_global, 3)
        ])

# %%
def aco_qap(
    fluxo: np.ndarray,
    distancia: np.ndarray,
    n_formigas: int = 10,
    alpha: float = 1,
    beta: float = 2,
    rho: float = 0.1,
    Q: float = 1,
    iter_max: int = 100,
    instancia: str = "desconhecida",
    tempo_inicio_global: float = None,
    tempo_global_max: float = None
) -> Tuple[List[int], int]:
    """
    Algoritmo de Otimização por Colônia de Formigas (ACO) puro com salvamento de resultados.
    """

    n: int = len(fluxo)
    heuristica: np.ndarray = 1 / (np.array(distancia) + 1e-10)
    feromonio: np.ndarray = inicializar_feromonio(n)

    melhor_solucao: Optional[List[int]] = None
    melhor_custo: float = float("inf")
    file_name = f"iteracoes_{instancia}_ACO.csv"

    for i in range(iter_max):
        if tempo_inicio_global and tempo_global_max:
            if (time.time() - tempo_inicio_global) > tempo_global_max:
                return melhor_solucao if melhor_solucao else [], int(melhor_custo)

        solucoes: List[List[int]] = []
        custos: List[int] = []

        for j in range(n_formigas):
            if tempo_inicio_global and tempo_global_max:
                if (time.time() - tempo_inicio_global) > tempo_global_max:
                    return melhor_solucao if melhor_solucao else [], int(melhor_custo)

            s: List[int] = construir_solucao_qap(feromonio, alpha, beta, heuristica)
            custo: int = calcular_aptidao_qap(s, fluxo, distancia)

            solucoes.append(s)
            custos.append(custo)

            if custo < melhor_custo:
                melhor_solucao, melhor_custo = s, custo

            save_aco_iteration_results(
                file_name=file_name,
                instancia=instancia,
                iteration=i,
                ant_index=j,
                best_cost=melhor_custo,
                current_cost=custo,
                tempo_inicio_global=tempo_inicio_global or time.time()
            )

        feromonio = atualizar_feromonio(feromonio, solucoes, custos, rho, Q)

        save_aco_iteration_results(
            file_name=file_name,
            instancia=instancia,
            iteration=i,
            ant_index=-1,  
            best_cost=melhor_custo,
            current_cost=min(custos),
            tempo_inicio_global=tempo_inicio_global or time.time()
        )

    return melhor_solucao if melhor_solucao else [], int(melhor_custo)

# %%
def ler_qap_com_n(caminho: str) -> Tuple[int, pd.DataFrame, pd.DataFrame]:
    with open(caminho, "r") as f:
        dados: List[int] = list(map(int, f.read().split()))

    n: int = dados[0]
    valores: List[int] = dados[1:]

    total_esperado: int = 2 * n * n
    if len(valores) != total_esperado:
        raise ValueError(f"Esperado {total_esperado} valores, mas encontrado {len(valores)}.")

    flow_flat: List[int] = valores[: n * n]
    dist_flat: List[int] = valores[n * n :]

    flow_df: pd.DataFrame = pd.DataFrame([flow_flat[i * n : (i + 1) * n] for i in range(n)])
    dist_df: pd.DataFrame = pd.DataFrame([dist_flat[i * n : (i + 1) * n] for i in range(n)])

    return n, flow_df, dist_df

# %%
if __name__ == "__main__":
    arquivos = glob.glob("*.txt")

    tempo_global_max = 10 * 60  # 10 minutos por instância

    for arquivo in arquivos:
        nome_instancia = os.path.splitext(os.path.basename(arquivo))[0]

        n, flow_df, dist_df = ler_qap_com_n(arquivo)
        matriz_fluxo = np.array(flow_df.values.tolist())
        matriz_distancia = np.array(dist_df.values.tolist())

        resultados = []
        tempo_inicio_instancia = time.time()

        for seed in range(42, 52):
            tempo_decorrido_global = time.time() - tempo_inicio_instancia
            if tempo_decorrido_global >= tempo_global_max:
                print(f"\n Tempo limite global atingido para {nome_instancia}.")
                break

            random.seed(seed)
            np.random.seed(seed)

            process = psutil.Process(os.getpid())
            tempo_inicio_seed = time.time()

            parametros = {
                "n_formigas": random.randint(5, 20),
                "alpha": random.uniform(0.5, 2.0),
                "beta": random.uniform(1.0, 3.0),
                "rho": random.uniform(0.05, 0.2),
                "Q": 1,
                "iter_max": random.randint(50, 150) 
            }

            melhor_solucao, melhor_custo = aco_qap(
                fluxo=matriz_fluxo,
                distancia=matriz_distancia,
                instancia=nome_instancia,
                tempo_inicio_global=tempo_inicio_instancia,
                tempo_global_max=tempo_global_max,
                **parametros
            )

            tempo_fim_seed = time.time()

            tempo_restante_global = max(0, tempo_global_max - (tempo_inicio_seed - tempo_inicio_instancia))
            tempo_execucao = min(tempo_fim_seed - tempo_inicio_seed, tempo_restante_global)

            try:
                memoria_usada = process.memory_info().peak_wset / (1024 * 1024)
            except AttributeError:
                memoria_usada = process.memory_info().rss / (1024 * 1024)

            resultados.append({
                "instancia": nome_instancia,
                "seed": seed,
                "melhor_solucao": melhor_solucao,
                "custo": melhor_custo,
                "tempo_execucao_segundos": round(tempo_execucao, 2),
                "memoria_usada_MB": round(memoria_usada, 2),
                **parametros
            })

            print(f"[{nome_instancia}] Seed {seed} finalizada. "
                  f"Custo: {melhor_custo} | Memória usada: {round(memoria_usada, 2)} MB")

        df_resultados = pd.DataFrame(resultados)
        df_resultados.to_csv(f"resultados_{nome_instancia}_ACO_10min.csv", index=False)

        print(f"\nResultados da instância {nome_instancia} salvos em resultados_{nome_instancia}_ACO.csv")
# Out:
# [Esc128] Seed 42 finalizada. Custo: 186 | Memória usada: 120.68 MB
# [Esc128] Seed 43 finalizada. Custo: 180 | Memória usada: 120.68 MB
# [Esc128] Seed 44 finalizada. Custo: 182 | Memória usada: 120.68 MB
# [Esc128] Seed 45 finalizada. Custo: 194 | Memória usada: 120.68 MB
# [Esc128] Seed 46 finalizada. Custo: 194 | Memória usada: 120.68 MB
# [Esc128] Seed 47 finalizada. Custo: 184 | Memória usada: 120.68 MB
# [Esc128] Seed 48 finalizada. Custo: 186 | Memória usada: 120.68 MB
# [Esc128] Seed 49 finalizada. Custo: 182 | Memória usada: 120.68 MB
# [Esc128] Seed 50 finalizada. Custo: 178 | Memória usada: 120.68 MB
#
#  Tempo limite global atingido para Esc128.
#
# Resultados da instância Esc128 salvos em resultados_Esc128_ACO.csv
# [Esc64a] Seed 42 finalizada. Custo: 162 | Memória usada: 120.68 MB
# [Esc64a] Seed 43 finalizada. Custo: 208 | Memória usada: 120.68 MB
# [Esc64a] Seed 44 finalizada. Custo: 202 | Memória usada: 120.68 MB
# [Esc64a] Seed 45 finalizada. Custo: 194 | Memória usada: 120.68 MB
# [Esc64a] Seed 46 finalizada. Custo: 214 | Memória usada: 120.68 MB
# [Esc64a] Seed 47 finalizada. Custo: 206 | Memória usada: 120.68 MB
# [Esc64a] Seed 48 finalizada. Custo: 190 | Memória usada: 120.68 MB
# [Esc64a] Seed 49 finalizada. Custo: 202 | Memória usada: 120.68 MB
# [Esc64a] Seed 50 finalizada. Custo: 202 | Memória usada: 120.68 MB
# [Esc64a] Seed 51 finalizada. Custo: 208 | Memória usada: 120.68 MB
#
# Resultados da instância Esc64a salvos em resultados_Esc64a_ACO.csv
# [Had12] Seed 42 finalizada. Custo: 1768 | Memória usada: 120.68 MB
# [Had12] Seed 43 finalizada. Custo: 1790 | Memória usada: 120.68 MB
# [Had12] Seed 44 finalizada. Custo: 1778 | Memória usada: 120.68 MB
# [Had12] Seed 45 finalizada. Custo: 1772 | Memória usada: 120.68 MB
# [Had12] Seed 46 finalizada. Custo: 1812 | Memória usada: 120.68 MB
# [Had12] Seed 47 finalizada. Custo: 1772 | Memória usada: 120.68 MB
# [Had12] Seed 48 finalizada. Custo: 1766 | Memória usada: 120.68 MB
# [Had12] Seed 49 finalizada. Custo: 1778 | Memória usada: 120.68 MB
# [Had12] Seed 50 finalizada. Custo: 1778 | Memória usada: 120.68 MB
# [Had12] Seed 51 finalizada. Custo: 1778 | Memória usada: 120.68 MB
#
# Resultados da instância Had12 salvos em resultados_Had12_ACO.csv
# [Had14] Seed 42 finalizada. Custo: 2986 | Memória usada: 120.68 MB
# [Had14] Seed 43 finalizada. Custo: 3036 | Memória usada: 120.68 MB
# [Had14] Seed 44 finalizada. Custo: 3014 | Memória usada: 120.68 MB
# [Had14] Seed 45 finalizada. Custo: 3032 | Memória usada: 120.68 MB
# [Had14] Seed 46 finalizada. Custo: 3038 | Memória usada: 120.68 MB
# [Had14] Seed 47 finalizada. Custo: 3008 | Memória usada: 120.68 MB
# [Had14] Seed 48 finalizada. Custo: 2988 | Memória usada: 120.68 MB
# [Had14] Seed 49 finalizada. Custo: 2992 | Memória usada: 120.68 MB
# [Had14] Seed 50 finalizada. Custo: 2994 | Memória usada: 120.68 MB
# [Had14] Seed 51 finalizada. Custo: 3008 | Memória usada: 120.68 MB
#
# Resultados da instância Had14 salvos em resultados_Had14_ACO.csv
# [Had16] Seed 42 finalizada. Custo: 4086 | Memória usada: 120.68 MB
# [Had16] Seed 43 finalizada. Custo: 4110 | Memória usada: 120.68 MB
# [Had16] Seed 44 finalizada. Custo: 4076 | Memória usada: 120.68 MB
# [Had16] Seed 45 finalizada. Custo: 4028 | Memória usada: 120.68 MB
# [Had16] Seed 46 finalizada. Custo: 4092 | Memória usada: 120.68 MB
# [Had16] Seed 47 finalizada. Custo: 4048 | Memória usada: 120.68 MB
# [Had16] Seed 48 finalizada. Custo: 4086 | Memória usada: 120.68 MB
# [Had16] Seed 49 finalizada. Custo: 4052 | Memória usada: 120.68 MB
# [Had16] Seed 50 finalizada. Custo: 4076 | Memória usada: 120.68 MB
# [Had16] Seed 51 finalizada. Custo: 4088 | Memória usada: 120.68 MB
#
# Resultados da instância Had16 salvos em resultados_Had16_ACO.csv
# [Had18] Seed 42 finalizada. Custo: 5842 | Memória usada: 120.68 MB
# [Had18] Seed 43 finalizada. Custo: 5902 | Memória usada: 120.68 MB
# [Had18] Seed 44 finalizada. Custo: 5752 | Memória usada: 120.68 MB
# [Had18] Seed 45 finalizada. Custo: 5764 | Memória usada: 120.68 MB
# [Had18] Seed 46 finalizada. Custo: 5858 | Memória usada: 120.68 MB
# [Had18] Seed 47 finalizada. Custo: 5822 | Memória usada: 120.68 MB
# [Had18] Seed 48 finalizada. Custo: 5838 | Memória usada: 120.68 MB
# [Had18] Seed 49 finalizada. Custo: 5850 | Memória usada: 120.68 MB
# [Had18] Seed 50 finalizada. Custo: 5862 | Memória usada: 120.68 MB
# [Had18] Seed 51 finalizada. Custo: 5818 | Memória usada: 120.68 MB
#
# Resultados da instância Had18 salvos em resultados_Had18_ACO.csv
# [Had20] Seed 42 finalizada. Custo: 7524 | Memória usada: 120.68 MB
# [Had20] Seed 43 finalizada. Custo: 7646 | Memória usada: 120.68 MB
# [Had20] Seed 44 finalizada. Custo: 7512 | Memória usada: 120.68 MB
# [Had20] Seed 45 finalizada. Custo: 7484 | Memória usada: 120.68 MB
# [Had20] Seed 46 finalizada. Custo: 7610 | Memória usada: 120.68 MB
# [Had20] Seed 47 finalizada. Custo: 7552 | Memória usada: 120.68 MB
# [Had20] Seed 48 finalizada. Custo: 7594 | Memória usada: 120.68 MB
# [Had20] Seed 49 finalizada. Custo: 7540 | Memória usada: 120.68 MB
# [Had20] Seed 50 finalizada. Custo: 7554 | Memória usada: 120.68 MB
# [Had20] Seed 51 finalizada. Custo: 7582 | Memória usada: 120.68 MB
#
# Resultados da instância Had20 salvos em resultados_Had20_ACO.csv
# [Kra30a] Seed 42 finalizada. Custo: 122000 | Memória usada: 120.68 MB
# [Kra30a] Seed 43 finalizada. Custo: 123070 | Memória usada: 120.68 MB
# [Kra30a] Seed 44 finalizada. Custo: 119760 | Memória usada: 120.68 MB
# [Kra30a] Seed 45 finalizada. Custo: 125780 | Memória usada: 120.68 MB
# [Kra30a] Seed 46 finalizada. Custo: 124270 | Memória usada: 120.68 MB
# [Kra30a] Seed 47 finalizada. Custo: 121120 | Memória usada: 120.68 MB
# [Kra30a] Seed 48 finalizada. Custo: 123990 | Memória usada: 120.68 MB
# [Kra30a] Seed 49 finalizada. Custo: 121680 | Memória usada: 120.68 MB
# [Kra30a] Seed 50 finalizada. Custo: 123100 | Memória usada: 120.68 MB
# [Kra30a] Seed 51 finalizada. Custo: 121890 | Memória usada: 120.68 MB
#
# Resultados da instância Kra30a salvos em resultados_Kra30a_ACO.csv
# [Kra30b] Seed 42 finalizada. Custo: 127310 | Memória usada: 120.68 MB
# [Kra30b] Seed 43 finalizada. Custo: 126480 | Memória usada: 120.68 MB
# [Kra30b] Seed 44 finalizada. Custo: 123800 | Memória usada: 120.68 MB
# [Kra30b] Seed 45 finalizada. Custo: 126590 | Memória usada: 120.68 MB
# [Kra30b] Seed 46 finalizada. Custo: 122030 | Memória usada: 120.68 MB
# [Kra30b] Seed 47 finalizada. Custo: 122880 | Memória usada: 120.68 MB
# [Kra30b] Seed 48 finalizada. Custo: 125250 | Memória usada: 120.68 MB
# [Kra30b] Seed 49 finalizada. Custo: 122630 | Memória usada: 120.68 MB
# [Kra30b] Seed 50 finalizada. Custo: 126320 | Memória usada: 120.68 MB
# [Kra30b] Seed 51 finalizada. Custo: 124540 | Memória usada: 120.68 MB
#
# Resultados da instância Kra30b salvos em resultados_Kra30b_ACO.csv
# [Kra32] Seed 42 finalizada. Custo: 118430 | Memória usada: 120.68 MB
# [Kra32] Seed 43 finalizada. Custo: 117890 | Memória usada: 120.68 MB
# [Kra32] Seed 44 finalizada. Custo: 113620 | Memória usada: 120.68 MB
# [Kra32] Seed 45 finalizada. Custo: 116080 | Memória usada: 120.68 MB
# [Kra32] Seed 46 finalizada. Custo: 113560 | Memória usada: 120.68 MB
# [Kra32] Seed 47 finalizada. Custo: 115270 | Memória usada: 120.68 MB
# [Kra32] Seed 48 finalizada. Custo: 114880 | Memória usada: 120.68 MB
# [Kra32] Seed 49 finalizada. Custo: 113220 | Memória usada: 120.68 MB
# [Kra32] Seed 50 finalizada. Custo: 115390 | Memória usada: 120.68 MB
# [Kra32] Seed 51 finalizada. Custo: 116260 | Memória usada: 120.68 MB
#
# Resultados da instância Kra32 salvos em resultados_Kra32_ACO.csv
# [Lipa20a] Seed 42 finalizada. Custo: 3889 | Memória usada: 120.68 MB
# [Lipa20a] Seed 43 finalizada. Custo: 3912 | Memória usada: 120.68 MB
# [Lipa20a] Seed 44 finalizada. Custo: 3891 | Memória usada: 120.68 MB
# [Lipa20a] Seed 45 finalizada. Custo: 3877 | Memória usada: 120.68 MB
# [Lipa20a] Seed 46 finalizada. Custo: 3905 | Memória usada: 120.68 MB
# [Lipa20a] Seed 47 finalizada. Custo: 3894 | Memória usada: 120.68 MB
# [Lipa20a] Seed 48 finalizada. Custo: 3902 | Memória usada: 120.68 MB
# [Lipa20a] Seed 49 finalizada. Custo: 3897 | Memória usada: 120.68 MB
# [Lipa20a] Seed 50 finalizada. Custo: 3886 | Memória usada: 120.68 MB
# [Lipa20a] Seed 51 finalizada. Custo: 3881 | Memória usada: 120.68 MB
#
# Resultados da instância Lipa20a salvos em resultados_Lipa20a_ACO.csv
# [Lipa20b] Seed 42 finalizada. Custo: 33626 | Memória usada: 120.68 MB
# [Lipa20b] Seed 43 finalizada. Custo: 34064 | Memória usada: 120.68 MB
# [Lipa20b] Seed 44 finalizada. Custo: 33733 | Memória usada: 120.68 MB
# [Lipa20b] Seed 45 finalizada. Custo: 33817 | Memória usada: 120.68 MB
# [Lipa20b] Seed 46 finalizada. Custo: 34082 | Memória usada: 120.68 MB
# [Lipa20b] Seed 47 finalizada. Custo: 33789 | Memória usada: 120.68 MB
# [Lipa20b] Seed 48 finalizada. Custo: 33789 | Memória usada: 120.68 MB
# [Lipa20b] Seed 49 finalizada. Custo: 34106 | Memória usada: 120.68 MB
# [Lipa20b] Seed 50 finalizada. Custo: 33506 | Memória usada: 120.68 MB
# [Lipa20b] Seed 51 finalizada. Custo: 34058 | Memória usada: 120.68 MB
#
# Resultados da instância Lipa20b salvos em resultados_Lipa20b_ACO.csv
# [Lipa30a] Seed 42 finalizada. Custo: 13660 | Memória usada: 120.68 MB
# [Lipa30a] Seed 43 finalizada. Custo: 13689 | Memória usada: 120.68 MB
# [Lipa30a] Seed 44 finalizada. Custo: 13673 | Memória usada: 120.68 MB
# [Lipa30a] Seed 45 finalizada. Custo: 13674 | Memória usada: 120.68 MB
# [Lipa30a] Seed 46 finalizada. Custo: 13678 | Memória usada: 120.68 MB
# [Lipa30a] Seed 47 finalizada. Custo: 13678 | Memória usada: 120.68 MB
# [Lipa30a] Seed 48 finalizada. Custo: 13683 | Memória usada: 120.68 MB
# [Lipa30a] Seed 49 finalizada. Custo: 13674 | Memória usada: 120.68 MB
# [Lipa30a] Seed 50 finalizada. Custo: 13698 | Memória usada: 120.68 MB
# [Lipa30a] Seed 51 finalizada. Custo: 13668 | Memória usada: 120.68 MB
#
# Resultados da instância Lipa30a salvos em resultados_Lipa30a_ACO.csv
# [Lipa30b] Seed 42 finalizada. Custo: 188791 | Memória usada: 120.68 MB
# [Lipa30b] Seed 43 finalizada. Custo: 187859 | Memória usada: 120.68 MB
# [Lipa30b] Seed 44 finalizada. Custo: 188288 | Memória usada: 120.68 MB
# [Lipa30b] Seed 45 finalizada. Custo: 189096 | Memória usada: 120.68 MB
# [Lipa30b] Seed 46 finalizada. Custo: 188062 | Memória usada: 120.68 MB
# [Lipa30b] Seed 47 finalizada. Custo: 188407 | Memória usada: 120.68 MB
# [Lipa30b] Seed 48 finalizada. Custo: 188238 | Memória usada: 120.68 MB
# [Lipa30b] Seed 49 finalizada. Custo: 188394 | Memória usada: 120.68 MB
# [Lipa30b] Seed 50 finalizada. Custo: 188810 | Memória usada: 120.68 MB
# [Lipa30b] Seed 51 finalizada. Custo: 187020 | Memória usada: 120.68 MB
#
# Resultados da instância Lipa30b salvos em resultados_Lipa30b_ACO.csv
# [Lipa40a] Seed 42 finalizada. Custo: 32498 | Memória usada: 120.68 MB
# [Lipa40a] Seed 43 finalizada. Custo: 32537 | Memória usada: 120.68 MB
# [Lipa40a] Seed 44 finalizada. Custo: 32468 | Memória usada: 120.68 MB
# [Lipa40a] Seed 45 finalizada. Custo: 32441 | Memória usada: 120.68 MB
# [Lipa40a] Seed 46 finalizada. Custo: 32512 | Memória usada: 120.68 MB
# [Lipa40a] Seed 47 finalizada. Custo: 32439 | Memória usada: 120.68 MB
# [Lipa40a] Seed 48 finalizada. Custo: 32485 | Memória usada: 120.68 MB
# [Lipa40a] Seed 49 finalizada. Custo: 32487 | Memória usada: 120.68 MB
# [Lipa40a] Seed 50 finalizada. Custo: 32466 | Memória usada: 120.68 MB
# [Lipa40a] Seed 51 finalizada. Custo: 32474 | Memória usada: 120.68 MB
#
# Resultados da instância Lipa40a salvos em resultados_Lipa40a_ACO.csv
# [Lipa40b] Seed 42 finalizada. Custo: 607287 | Memória usada: 120.68 MB
# [Lipa40b] Seed 43 finalizada. Custo: 603199 | Memória usada: 120.68 MB
# [Lipa40b] Seed 44 finalizada. Custo: 603147 | Memória usada: 120.68 MB
# [Lipa40b] Seed 45 finalizada. Custo: 607399 | Memória usada: 120.68 MB
# [Lipa40b] Seed 46 finalizada. Custo: 609814 | Memória usada: 120.68 MB
# [Lipa40b] Seed 47 finalizada. Custo: 605301 | Memória usada: 120.68 MB
# [Lipa40b] Seed 48 finalizada. Custo: 605071 | Memória usada: 120.68 MB
# [Lipa40b] Seed 49 finalizada. Custo: 602540 | Memória usada: 120.68 MB
# [Lipa40b] Seed 50 finalizada. Custo: 608276 | Memória usada: 120.68 MB
# [Lipa40b] Seed 51 finalizada. Custo: 604935 | Memória usada: 120.68 MB
#
# Resultados da instância Lipa40b salvos em resultados_Lipa40b_ACO.csv
# [Lipa50a] Seed 42 finalizada. Custo: 63707 | Memória usada: 120.68 MB
# [Lipa50a] Seed 43 finalizada. Custo: 63744 | Memória usada: 120.68 MB
# [Lipa50a] Seed 44 finalizada. Custo: 63681 | Memória usada: 120.68 MB
# [Lipa50a] Seed 45 finalizada. Custo: 63777 | Memória usada: 120.68 MB
# [Lipa50a] Seed 46 finalizada. Custo: 63755 | Memória usada: 120.68 MB
# [Lipa50a] Seed 47 finalizada. Custo: 63740 | Memória usada: 120.68 MB
# [Lipa50a] Seed 48 finalizada. Custo: 63661 | Memória usada: 120.68 MB
# [Lipa50a] Seed 49 finalizada. Custo: 63718 | Memória usada: 120.68 MB
# [Lipa50a] Seed 50 finalizada. Custo: 63736 | Memória usada: 120.68 MB
# [Lipa50a] Seed 51 finalizada. Custo: 63743 | Memória usada: 120.68 MB
#
# Resultados da instância Lipa50a salvos em resultados_Lipa50a_ACO.csv
# [Lipa50b] Seed 42 finalizada. Custo: 1531635 | Memória usada: 120.68 MB
# [Lipa50b] Seed 43 finalizada. Custo: 1536376 | Memória usada: 120.68 MB
# [Lipa50b] Seed 44 finalizada. Custo: 1525568 | Memória usada: 120.68 MB
# [Lipa50b] Seed 45 finalizada. Custo: 1525959 | Memória usada: 120.68 MB
# [Lipa50b] Seed 46 finalizada. Custo: 1528598 | Memória usada: 120.68 MB
# [Lipa50b] Seed 47 finalizada. Custo: 1529937 | Memória usada: 120.68 MB
# [Lipa50b] Seed 48 finalizada. Custo: 1525313 | Memória usada: 120.68 MB
# [Lipa50b] Seed 49 finalizada. Custo: 1532482 | Memória usada: 120.68 MB
# [Lipa50b] Seed 50 finalizada. Custo: 1529578 | Memória usada: 120.68 MB
# [Lipa50b] Seed 51 finalizada. Custo: 1529433 | Memória usada: 120.68 MB
#
# Resultados da instância Lipa50b salvos em resultados_Lipa50b_ACO.csv
# [Lipa60a] Seed 42 finalizada. Custo: 109660 | Memória usada: 120.68 MB
# [Lipa60a] Seed 43 finalizada. Custo: 109602 | Memória usada: 120.68 MB
# [Lipa60a] Seed 44 finalizada. Custo: 109635 | Memória usada: 120.68 MB
# [Lipa60a] Seed 45 finalizada. Custo: 109705 | Memória usada: 120.68 MB
# [Lipa60a] Seed 46 finalizada. Custo: 109749 | Memória usada: 120.68 MB
# [Lipa60a] Seed 47 finalizada. Custo: 109532 | Memória usada: 120.68 MB
# [Lipa60a] Seed 48 finalizada. Custo: 109597 | Memória usada: 120.68 MB
# [Lipa60a] Seed 49 finalizada. Custo: 109689 | Memória usada: 120.68 MB
# [Lipa60a] Seed 50 finalizada. Custo: 109682 | Memória usada: 120.68 MB
# [Lipa60a] Seed 51 finalizada. Custo: 109725 | Memória usada: 120.68 MB
#
# Resultados da instância Lipa60a salvos em resultados_Lipa60a_ACO.csv
# [Lipa60b] Seed 42 finalizada. Custo: 3202416 | Memória usada: 120.68 MB
# [Lipa60b] Seed 43 finalizada. Custo: 3221626 | Memória usada: 120.68 MB
# [Lipa60b] Seed 44 finalizada. Custo: 3205520 | Memória usada: 120.68 MB
# [Lipa60b] Seed 45 finalizada. Custo: 3212519 | Memória usada: 120.68 MB
# [Lipa60b] Seed 46 finalizada. Custo: 3213833 | Memória usada: 120.68 MB
# [Lipa60b] Seed 47 finalizada. Custo: 3214256 | Memória usada: 120.68 MB
# [Lipa60b] Seed 48 finalizada. Custo: 3210407 | Memória usada: 120.68 MB
# [Lipa60b] Seed 49 finalizada. Custo: 3214215 | Memória usada: 120.68 MB
# [Lipa60b] Seed 50 finalizada. Custo: 3198612 | Memória usada: 120.68 MB
# [Lipa60b] Seed 51 finalizada. Custo: 3207107 | Memória usada: 120.68 MB
#
# Resultados da instância Lipa60b salvos em resultados_Lipa60b_ACO.csv
