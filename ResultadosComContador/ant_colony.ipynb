# %%
import numpy as np
import random
import pandas as pd
import psutil
import os
import time
import glob
from typing import List, Tuple, Union, Optional
import csv

# %%
def gerar_array_replicavel(seed: int, tamanho: int) -> List[int]:
    random.seed(seed)
    vetor = list(range(tamanho))
    random.shuffle(vetor)
    return vetor

# %%
def calcular_aptidao_qap(
    solucao: Union[List[int], np.ndarray, List[List[int]]],
    matriz_fluxo: np.ndarray,
    matriz_distancia: np.ndarray
) -> int:
    solucao_flat: List[int] = []
    for x in solucao:
        if isinstance(x, (list, np.ndarray)):
            solucao_flat.extend(int(v) for v in x)
        else:
            solucao_flat.append(int(x))

    n: int = len(solucao_flat)
    custo: int = 0
    for i in range(n):
        for j in range(n):
            custo += matriz_fluxo[i][j] * matriz_distancia[solucao_flat[i]][solucao_flat[j]]
    return custo

# %%
def inicializar_feromonio(n: int, valor_inicial: float = 0.1) -> np.ndarray:
    return np.full((n, n), valor_inicial)

# %%
def construir_solucao_qap(
    feromonio: np.ndarray,
    alpha: float,
    beta: float,
    heuristica: np.ndarray
) -> List[int]:
    """
    feromonio -> memória coletiva das soluções anteriores 
    heuristica -> informação local que guia a escolha 
    alpha -> peso do feromônio
    beta -> peso da heurística
    """
    n: int = feromonio.shape[0]
    nao_visitados: List[int] = list(range(n))
    solucao: List[int] = []

    while nao_visitados:
        if not solucao:
            atual: int = random.choice(nao_visitados)
        else:
            ultima: int = solucao[-1]
            pesos: List[float] = []
            for prox in nao_visitados:
                tau: float = feromonio[ultima][prox] ** alpha
                eta: float = heuristica[ultima][prox] ** beta
                pesos.append(tau * eta)
            pesos_np: np.ndarray = np.array(pesos, dtype=float)
            if not np.isfinite(pesos_np).all() or pesos_np.sum() <= 0:
                pesos_np = np.ones_like(pesos_np) / len(pesos_np)
            else:
                pesos_np /= pesos_np.sum()
            atual = random.choices(nao_visitados, weights=pesos_np)[0]


        solucao.append(atual)
        nao_visitados.remove(atual)

    return solucao

# %%
def busca_local(
    solucao: List[int],
    fluxo: np.ndarray,
    distancia: np.ndarray,
    tempo_inicio_global: float = None,  
    tempo_global_max: float = None     
) -> List[int]:
    melhor: List[int] = solucao.copy()
    melhor_custo: int = calcular_aptidao_qap(melhor, fluxo, distancia)
    melhorou: bool = True
    
    while melhorou:
        if tempo_inicio_global and tempo_global_max:
            if (time.time() - tempo_inicio_global) > tempo_global_max:
                return melhor 
        
        melhorou = False
        for i in range(len(solucao) - 1):
            if tempo_inicio_global and tempo_global_max:
                if (time.time() - tempo_inicio_global) > tempo_global_max:
                    return melhor
            
            for j in range(i + 1, len(solucao)):
                nova: List[int] = melhor.copy()
                nova[i], nova[j] = nova[j], nova[i]
                custo_novo: int = calcular_aptidao_qap(nova, fluxo, distancia)
                if custo_novo < melhor_custo:
                    melhor, melhor_custo = nova, custo_novo
                    melhorou = True
    return melhor

# %%
def atualizar_feromonio(
    feromonio: np.ndarray,
    solucoes: List[List[int]],
    custos: List[int],
    rho: float,
    Q: float
) -> np.ndarray:
    feromonio *= (1 - rho)  
    for solucao, custo in zip(solucoes, custos):
        if custo <= 0 or not np.isfinite(custo):
            custo = 1e-6 
        deposito: float = Q / custo

        for i in range(len(solucao) - 1):
            feromonio[solucao[i]][solucao[i + 1]] += deposito
        feromonio[solucao[-1]][solucao[0]] += deposito
    return feromonio

# %%
def save_aco_iteration_results(
    file_name: str,
    instancia: str,
    iteration: int,
    ant_index: int,
    best_cost: float,
    current_cost: float,
    tempo_inicio_global: float
) -> None:
    """
    Salva resultados parciais da execução do ACO em um arquivo CSV no mesmo diretório.
    """
    path = file_name  

    header = [
        "instancia",
        "iteracao",
        "formiga",
        "melhor_custo",
        "custo_atual",
        "tempo_decorrido"
    ]
    write_header = not os.path.exists(path)

    with open(path, mode="a", newline="") as f:
        writer = csv.writer(f)
        if write_header:
            writer.writerow(header)
        writer.writerow([
            instancia,
            iteration,
            ant_index,
            best_cost,
            current_cost,
            round(time.time() - tempo_inicio_global, 3)
        ])

# %%
def aco_qap(
    fluxo: np.ndarray,
    distancia: np.ndarray,
    n_formigas: int = 10,
    alpha: float = 1,
    beta: float = 2,
    rho: float = 0.1,
    Q: float = 1,
    iter_max: int = 100,
    instancia: str = "desconhecida",
    tempo_inicio_global: float = None,
    tempo_global_max: float = None,
    tempo_max: float = None,
    parametros: dict = None,
    seed:int = 42
) -> Tuple[List[int], int]:
    """
    Algoritmo de Otimização por Colônia de Formigas (ACO) com controle de tempo local/global
    e salvamento periódico de progresso.
    """

    if parametros is None:
        parametros = {}

    n: int = len(fluxo)
    heuristica: np.ndarray = 1 / (np.array(distancia) + 1e-10)
    feromonio: np.ndarray = inicializar_feromonio(n)

    melhor_solucao: Optional[List[int]] = None
    melhor_custo: float = float("inf")
    file_name = f"iteracoes_{instancia}_ACO.csv"

    inicio_local = time.time()
    iteration = 0

    for i in range(iter_max):
        iteration += 1

        # --- Controle de tempo global ---
        if tempo_inicio_global and tempo_global_max:
            if (time.time() - tempo_inicio_global) > tempo_global_max:
                print(f"[{instancia}] Tempo limite global atingido (ACO).")
                break

        # --- Controle de tempo local (tempo_max, se existir) ---
        if tempo_max and (time.time() - inicio_local) > tempo_max:
            print(f"[{instancia}] Tempo máximo local atingido (ACO).")
            break

        solucoes: List[List[int]] = []
        custos: List[int] = []

        for j in range(n_formigas):
            # Parada global (durante construção)
            if tempo_inicio_global and tempo_global_max:
                if (time.time() - tempo_inicio_global) > tempo_global_max:
                    print(f"[{instancia}] Parada global durante iteração {i}.")
                    break

            s: List[int] = construir_solucao_qap(feromonio, alpha, beta, heuristica)
            custo: int = calcular_aptidao_qap(s, fluxo, distancia)

            solucoes.append(s)
            custos.append(custo)

            if custo < melhor_custo:
                melhor_solucao, melhor_custo = s, custo

            # --- Salvamento por formiga ---
            save_aco_iteration_results(
                file_name=file_name,
                instancia=instancia,
                iteration=i,
                ant_index=j,
                best_cost=melhor_custo,
                current_cost=custo,
                tempo_inicio_global=tempo_inicio_global or inicio_local
            )

        # Atualiza feromônio após todas as formigas
        feromonio = atualizar_feromonio(feromonio, solucoes, custos, rho, Q)

        # --- Salvamento por iteração ---
        save_aco_iteration_results(
            file_name=file_name,
            instancia=instancia,
            iteration=i,
            ant_index=-1,
            best_cost=melhor_custo,
            current_cost=min(custos),
            tempo_inicio_global=tempo_inicio_global or inicio_local
        )

    return melhor_solucao if melhor_solucao else [], int(melhor_custo)

# %%
def ler_qap_com_n(caminho: str) -> Tuple[int, pd.DataFrame, pd.DataFrame]:
    with open(caminho, "r") as f:
        dados: List[int] = list(map(int, f.read().split()))

    n: int = dados[0]
    valores: List[int] = dados[1:]

    total_esperado: int = 2 * n * n
    if len(valores) != total_esperado:
        raise ValueError(f"Esperado {total_esperado} valores, mas encontrado {len(valores)}.")

    flow_flat: List[int] = valores[: n * n]
    dist_flat: List[int] = valores[n * n :]

    flow_df: pd.DataFrame = pd.DataFrame([flow_flat[i * n : (i + 1) * n] for i in range(n)])
    dist_df: pd.DataFrame = pd.DataFrame([dist_flat[i * n : (i + 1) * n] for i in range(n)])

    return n, flow_df, dist_df

# %%
if __name__ == "__main__":
    arquivos = glob.glob("*.txt")
    tempo_global_max = 10 * 60  # 10 minutos por instância

    for arquivo in arquivos:
        nome_instancia = os.path.splitext(os.path.basename(arquivo))[0]
        n, flow_df, dist_df = ler_qap_com_n(arquivo)
        matriz_fluxo = np.array(flow_df.values.tolist())
        matriz_distancia = np.array(dist_df.values.tolist())

        resultados = []
        tempo_inicio_instancia = time.time()

        for seed in range(42, 52):
            if (time.time() - tempo_inicio_instancia) >= tempo_global_max:
                print(f"\n Tempo limite global atingido para {nome_instancia}.")
                break

            process = psutil.Process(os.getpid())
            tempo_inicio_seed = time.time()

            parametros = {
                "instancia": nome_instancia,
                "n_formigas": random.randint(5, 20),
                "alpha": random.uniform(0.5, 2.0),
                "beta": random.uniform(1.0, 3.0),
                "rho": random.uniform(0.05, 0.2),
                "Q": 1,
                "iter_max": random.randint(50, 150),
                "seed": seed
            }

            melhor_solucao, melhor_custo = aco_qap(
                fluxo=matriz_fluxo,
                distancia=matriz_distancia,
                tempo_inicio_global=tempo_inicio_instancia,
                tempo_global_max=tempo_global_max,
                tempo_max=parametros["iter_max"] * 0.5, 
                parametros=parametros,
                **parametros
            )

            tempo_fim_seed = time.time()
            tempo_execucao = min(
                tempo_fim_seed - tempo_inicio_seed,
                max(0, tempo_global_max - (tempo_inicio_seed - tempo_inicio_instancia))
            )

            try:
                memoria_usada = process.memory_info().peak_wset / (1024 * 1024)
            except AttributeError:
                memoria_usada = process.memory_info().rss / (1024 * 1024)

            resultados.append({
                "instancia": nome_instancia,
                "seed": seed,
                "melhor_solucao": melhor_solucao,
                "custo": melhor_custo,
                "tempo_execucao_segundos": round(tempo_execucao, 2),
                "memoria_usada_MB": round(memoria_usada, 2),
                **parametros
            })

            print(f"[{nome_instancia}] Seed {seed} finalizada. "
                  f"Custo: {melhor_custo} | Memória usada: {round(memoria_usada, 2)} MB")

        df_resultados = pd.DataFrame(resultados)
        df_resultados.to_csv(f"resultados_{nome_instancia}_ACO_10min.csv", index=False)
        print(f"\n Resultados da instância {nome_instancia} salvos em resultados_{nome_instancia}_ACO_10min.csv")
# Out:
# [Bur26a] Seed 42 finalizada. Custo: 5669255 | Memória usada: 131.55 MB
# [Bur26a] Seed 43 finalizada. Custo: 5679696 | Memória usada: 131.55 MB
# [Bur26a] Seed 44 finalizada. Custo: 5638395 | Memória usada: 131.55 MB
# [Bur26a] Seed 45 finalizada. Custo: 5644793 | Memória usada: 131.55 MB
# [Bur26a] Seed 46 finalizada. Custo: 5643471 | Memória usada: 131.55 MB
# [Bur26a] Seed 47 finalizada. Custo: 5684157 | Memória usada: 131.55 MB
# [Bur26a] Seed 48 finalizada. Custo: 5685725 | Memória usada: 131.55 MB
# [Bur26a] Seed 49 finalizada. Custo: 5629228 | Memória usada: 131.55 MB
# [Bur26a] Seed 50 finalizada. Custo: 5704174 | Memória usada: 131.55 MB
# [Bur26a] Seed 51 finalizada. Custo: 5664172 | Memória usada: 131.55 MB
#
#  Resultados da instância Bur26a salvos em resultados_Bur26a_ACO_10min.csv
# [Chr12a] Seed 42 finalizada. Custo: 23878 | Memória usada: 131.55 MB
# [Chr12a] Seed 43 finalizada. Custo: 21358 | Memória usada: 131.55 MB
# [Chr12a] Seed 44 finalizada. Custo: 23590 | Memória usada: 131.55 MB
# [Chr12a] Seed 45 finalizada. Custo: 25846 | Memória usada: 131.55 MB
# [Chr12a] Seed 46 finalizada. Custo: 22380 | Memória usada: 131.55 MB
# [Chr12a] Seed 47 finalizada. Custo: 23064 | Memória usada: 131.55 MB
# [Chr12a] Seed 48 finalizada. Custo: 21358 | Memória usada: 131.55 MB
# [Chr12a] Seed 49 finalizada. Custo: 24224 | Memória usada: 131.55 MB
# [Chr12a] Seed 50 finalizada. Custo: 21028 | Memória usada: 131.55 MB
# [Chr12a] Seed 51 finalizada. Custo: 21160 | Memória usada: 131.55 MB
#
#  Resultados da instância Chr12a salvos em resultados_Chr12a_ACO_10min.csv
# [Els19] Seed 42 finalizada. Custo: 29987800 | Memória usada: 131.55 MB
# [Els19] Seed 43 finalizada. Custo: 25710516 | Memória usada: 131.55 MB
# [Els19] Seed 44 finalizada. Custo: 28208146 | Memória usada: 131.55 MB
# [Els19] Seed 45 finalizada. Custo: 26055408 | Memória usada: 131.55 MB
# [Els19] Seed 46 finalizada. Custo: 26410610 | Memória usada: 131.55 MB
# [Els19] Seed 47 finalizada. Custo: 29360690 | Memória usada: 131.55 MB
# [Els19] Seed 48 finalizada. Custo: 32761576 | Memória usada: 131.55 MB
# [Els19] Seed 49 finalizada. Custo: 29255480 | Memória usada: 131.55 MB
# [Els19] Seed 50 finalizada. Custo: 27085412 | Memória usada: 131.55 MB
# [Els19] Seed 51 finalizada. Custo: 27045200 | Memória usada: 131.55 MB
#
#  Resultados da instância Els19 salvos em resultados_Els19_ACO_10min.csv
# [Esc16a] Seed 42 finalizada. Custo: 76 | Memória usada: 131.55 MB
# [Esc16a] Seed 43 finalizada. Custo: 76 | Memória usada: 131.55 MB
# [Esc16a] Seed 44 finalizada. Custo: 76 | Memória usada: 131.55 MB
# [Esc16a] Seed 45 finalizada. Custo: 76 | Memória usada: 131.55 MB
# [Esc16a] Seed 46 finalizada. Custo: 76 | Memória usada: 131.55 MB
# [Esc16a] Seed 47 finalizada. Custo: 76 | Memória usada: 131.55 MB
# [Esc16a] Seed 48 finalizada. Custo: 76 | Memória usada: 131.55 MB
# [Esc16a] Seed 49 finalizada. Custo: 76 | Memória usada: 131.55 MB
# [Esc16a] Seed 50 finalizada. Custo: 76 | Memória usada: 131.55 MB
# [Esc16a] Seed 51 finalizada. Custo: 76 | Memória usada: 131.55 MB
#
#  Resultados da instância Esc16a salvos em resultados_Esc16a_ACO_10min.csv
# [Esc32a] Seed 42 finalizada. Custo: 302 | Memória usada: 131.55 MB
# [Esc32a] Seed 43 finalizada. Custo: 314 | Memória usada: 131.55 MB
# [Esc32a] Seed 44 finalizada. Custo: 310 | Memória usada: 131.55 MB
# [Esc32a] Seed 45 finalizada. Custo: 310 | Memória usada: 131.55 MB
# [Esc32a] Seed 46 finalizada. Custo: 302 | Memória usada: 131.55 MB
# [Esc32a] Seed 47 finalizada. Custo: 322 | Memória usada: 131.55 MB
# [Esc32a] Seed 48 finalizada. Custo: 304 | Memória usada: 131.55 MB
# [Esc32a] Seed 49 finalizada. Custo: 318 | Memória usada: 131.55 MB
# [Esc32a] Seed 50 finalizada. Custo: 314 | Memória usada: 131.55 MB
# [Esc32a] Seed 51 finalizada. Custo: 314 | Memória usada: 131.55 MB
#
#  Resultados da instância Esc32a salvos em resultados_Esc32a_ACO_10min.csv
# [Had12] Seed 42 finalizada. Custo: 1798 | Memória usada: 131.55 MB
# [Had12] Seed 43 finalizada. Custo: 1778 | Memória usada: 131.55 MB
# [Had12] Seed 44 finalizada. Custo: 1786 | Memória usada: 131.55 MB
# [Had12] Seed 45 finalizada. Custo: 1778 | Memória usada: 131.55 MB
# [Had12] Seed 46 finalizada. Custo: 1744 | Memória usada: 131.55 MB
# [Had12] Seed 47 finalizada. Custo: 1778 | Memória usada: 131.55 MB
# [Had12] Seed 48 finalizada. Custo: 1778 | Memória usada: 131.55 MB
# [Had12] Seed 49 finalizada. Custo: 1762 | Memória usada: 131.55 MB
# [Had12] Seed 50 finalizada. Custo: 1746 | Memória usada: 131.55 MB
# [Had12] Seed 51 finalizada. Custo: 1744 | Memória usada: 131.55 MB
#
#  Resultados da instância Had12 salvos em resultados_Had12_ACO_10min.csv
# [Kra30a] Seed 42 finalizada. Custo: 123650 | Memória usada: 131.55 MB
# [Kra30a] Seed 43 finalizada. Custo: 121900 | Memória usada: 131.55 MB
# [Kra30a] Seed 44 finalizada. Custo: 120630 | Memória usada: 131.55 MB
# [Kra30a] Seed 45 finalizada. Custo: 123830 | Memória usada: 131.55 MB
# [Kra30a] Seed 46 finalizada. Custo: 124320 | Memória usada: 131.55 MB
# [Kra30a] Seed 47 finalizada. Custo: 122980 | Memória usada: 131.55 MB
# [Kra30a] Seed 48 finalizada. Custo: 124180 | Memória usada: 131.55 MB
# [Kra30a] Seed 49 finalizada. Custo: 123820 | Memória usada: 131.55 MB
# [Kra30a] Seed 50 finalizada. Custo: 121340 | Memória usada: 131.55 MB
# [Kra30a] Seed 51 finalizada. Custo: 121830 | Memória usada: 131.55 MB
#
#  Resultados da instância Kra30a salvos em resultados_Kra30a_ACO_10min.csv
# [Lipa20a] Seed 42 finalizada. Custo: 3890 | Memória usada: 131.55 MB
# [Lipa20a] Seed 43 finalizada. Custo: 3861 | Memória usada: 131.55 MB
# [Lipa20a] Seed 44 finalizada. Custo: 3891 | Memória usada: 131.55 MB
# [Lipa20a] Seed 45 finalizada. Custo: 3903 | Memória usada: 131.55 MB
# [Lipa20a] Seed 46 finalizada. Custo: 3901 | Memória usada: 131.55 MB
# [Lipa20a] Seed 47 finalizada. Custo: 3909 | Memória usada: 131.55 MB
# [Lipa20a] Seed 48 finalizada. Custo: 3881 | Memória usada: 131.55 MB
# [Lipa20a] Seed 49 finalizada. Custo: 3894 | Memória usada: 131.55 MB
# [Lipa20a] Seed 50 finalizada. Custo: 3877 | Memória usada: 131.55 MB
# [Lipa20a] Seed 51 finalizada. Custo: 3888 | Memória usada: 131.55 MB
#
#  Resultados da instância Lipa20a salvos em resultados_Lipa20a_ACO_10min.csv
# [Tai256c] Tempo máximo local atingido (ACO).
# [Tai256c] Seed 42 finalizada. Custo: 50539342 | Memória usada: 131.55 MB
# [Tai256c] Tempo máximo local atingido (ACO).
# [Tai256c] Seed 43 finalizada. Custo: 50481440 | Memória usada: 131.55 MB
# [Tai256c] Tempo máximo local atingido (ACO).
# [Tai256c] Seed 44 finalizada. Custo: 50731458 | Memória usada: 131.55 MB
# [Tai256c] Tempo máximo local atingido (ACO).
# [Tai256c] Seed 45 finalizada. Custo: 50751784 | Memória usada: 131.55 MB
# [Tai256c] Tempo máximo local atingido (ACO).
# [Tai256c] Seed 46 finalizada. Custo: 51298890 | Memória usada: 131.55 MB
# [Tai256c] Tempo máximo local atingido (ACO).
# [Tai256c] Seed 47 finalizada. Custo: 50326494 | Memória usada: 131.55 MB
# [Tai256c] Tempo máximo local atingido (ACO).
# [Tai256c] Seed 48 finalizada. Custo: 50992864 | Memória usada: 131.55 MB
# [Tai256c] Tempo máximo local atingido (ACO).
# [Tai256c] Seed 49 finalizada. Custo: 50879618 | Memória usada: 131.55 MB
# [Tai256c] Tempo máximo local atingido (ACO).
# [Tai256c] Seed 50 finalizada. Custo: 50933028 | Memória usada: 131.55 MB
# [Tai256c] Tempo máximo local atingido (ACO).
# [Tai256c] Seed 51 finalizada. Custo: 51338580 | Memória usada: 131.55 MB
#
#  Resultados da instância Tai256c salvos em resultados_Tai256c_ACO_10min.csv
# [Wil50] Seed 42 finalizada. Custo: 55028 | Memória usada: 131.55 MB
# [Wil50] Seed 43 finalizada. Custo: 54940 | Memória usada: 131.55 MB
# [Wil50] Seed 44 finalizada. Custo: 55224 | Memória usada: 131.55 MB
# [Wil50] Seed 45 finalizada. Custo: 55364 | Memória usada: 131.55 MB
# [Wil50] Seed 46 finalizada. Custo: 55302 | Memória usada: 131.55 MB
# [Wil50] Seed 47 finalizada. Custo: 54960 | Memória usada: 131.55 MB
# [Wil50] Seed 48 finalizada. Custo: 55306 | Memória usada: 131.55 MB
# [Wil50] Seed 49 finalizada. Custo: 55240 | Memória usada: 131.55 MB
# [Wil50] Seed 50 finalizada. Custo: 55318 | Memória usada: 131.55 MB
# [Wil50] Seed 51 finalizada. Custo: 55106 | Memória usada: 131.55 MB
#
#  Resultados da instância Wil50 salvos em resultados_Wil50_ACO_10min.csv
